# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet('../corpus/articles_2026-07-26.parquet')
df.head()
# Out:
#                              article_id source_dataset publisher  \
# 0  54b2c406-5cfc-5961-8b15-84c621f5f7f5        lk_news       Ada
# 1  125dfc83-cf62-5029-a8e3-0d6c7dee252b        lk_news       Ada
# 2  57cd20b8-aaa3-50ef-8ad6-5d67eb3eb02e        lk_news       Ada
# 3  8ccc851b-1149-5eb4-b4cc-463f1f4edf46        lk_news       Ada
# 4  e1a24a10-b1ab-51c5-aca3-4cb8da2c7deb        lk_news       Ada
#
#                                                  url  \
# 0  https://www.ada.lk/breaking_news/මරණ-තර්ජන-කළ-...
# 1  https://www.ada.lk/breaking_news/අගමැතිගේ--ඇමත...
# 2  https://www.ada.lk/breaking_news/රු--2000-නෝට්...
# 3  https://www.ada.lk/breaking_news/ක්ලබ්-වසන්ත-ඝ...
# 4  https://www.ada.lk/breaking_news/බිරිය-හා-තවත්...
#
#                published_at  \
# 0 2025-08-05 00:00:00+00:00
# 1 2024-03-25 00:00:00+00:00
# 2 2025-09-15 00:00:00+00:00
# 3 2024-07-24 00:00:00+00:00
# 4 2024-04-19 00:00:00+00:00
#
#                                                title  \
# ...
